# %%
#  hachoir
import requests
from random import randint
from time import sleep
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Maintenant nous avons un résumé au dessus de la fonction 
def get_url_tunisianet(urls=[], url=None, n=0):
    url_articles = []
    if n > 2:
        for page in range(2,n):
            url = f'{url}={page}'
            response = requests.get(url)
            page_contents = response.text
            if response.status_code != 200:
                raise Exception('Failed to load page {}'.format(items_url))
            doc = BeautifulSoup(page_contents, "html.parser")
            for item in doc.find_all("a", {'class': "thumbnail product-thumbnail first-img"}):
                url_articles.append(item['href'])
   
    for page in urls:
        url = page
        response = requests.get(url)
        page_contents = response.text
        if response.status_code != 200:
            raise Exception('Failed to load page {}'.format(items_url))
        doc = BeautifulSoup(page_contents, "html.parser")
        for item in doc.find_all("a", {'class': "thumbnail product-thumbnail first-img"}):
            url_articles.append(item['href'])
        
    return url_articles

# %%
def get_article(items_url):
    images_articles = []
    # télécharger la page
    response = requests.get(items_url)
    # vérifier le succès de réponse
    if response.status_code != 200:
        raise Exception('Failed to load page {}'.format(items_url))
    # Parser la réponse à l'aide de beaufifulSoup
    doc = BeautifulSoup(response.text, 'html.parser')
    for i, img in enumerate(doc.find_all('a', {'class': 'thumb-container'})):
        if i>= 1 and len(doc.find_all('a', {'class': 'thumb-container'})) > 1:
            images_articles.append(img['data-image'])
    return images_articles

# %%
import random
import urllib.request
import os

def download_artciles(urls, doc):
    
    os.makedirs(os.path.join('images', doc))
    for i, url in enumerate(urls):
        try:
            fullname =  "images/" + doc + "/" + str((i+1))+".jpg"
            urllib.request.urlretrieve(url,fullname)
        except:
            pass

# %%
def enregistrer_images(images_articles, dir_name):
    images_articles = []
    for url in images_articles:
        for image in get_article(url):
            images_articles.append(image)

    # download_artciles(images_tondeuses, dir_name)
    return images_articles

# %%
def tunisianet_scraping_images(urls, url, n, dir_name):
    images = []
    url_article = get_url_tunisianet(urls, url, n)
    for uri in url_article:
        for u in get_article(uri):
            images.append(u)
            
    download_artciles(images, dir_name)
    return len(f'{len(images)} images')

# %%
# tunisianet_scraping_images(
#     ["https://www.tunisianet.com.tn/457-climatiseur-tunisie-chaud-froid"],
#     "https://www.tunisianet.com.tn/457-climatiseur-tunisie-chaud-froid?page=",
#     4,
#     "climatiseur"
# )

# %%
tests = [
{
        "urls": ["https://www.tunisianet.com.tn/713-ventilateur-tunisie"],
        "url": None,
        "page": 0,
        "dossier": "ventilateur"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/705-vehicules-electrique"],
        "url": None,
        "page": 0,
        "dossier": "vehicules_electrique"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/630-camera-de-surveillance"],
        "url": "https://www.tunisianet.com.tn/630-camera-de-surveillance?page=",
        "page": 3,
        "dossier": "camera_de_surveillance"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/634-enregistreur-dvr-nvr"],
        "url": None,
        "page": 0,
        "dossier": "enregistreur_dvr"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/631-detecteurs-et-capteurs"],
        "url": None,
        "page": 0,
        "dossier": "detecteur_ou_capteur"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/576-tiroirs-caisses-et-coffres-forts"],
        "url": None,
        "page": 0,
        "dossier": "tiroirs-caisses_ou_coffres_fort"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/577-caisses-enregistreuses"],
        "url": None,
        "page": 0,
        "dossier": "caisse_enregistreuse"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/578-douchettes"],
        "url": None,
        "page": 0,
        "dossier": "douchette"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/579-destructeurs-de-papiers"],
        "url": None,
        "page": 0,
        "dossier": "destructeurs_de_papiers"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/580-perforelieuses"],
        "url": None,
        "page": 0,
        "dossier": "perforelieuse"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/581-imprimante-point-de-vente"],
        "url": None,
        "page": 0,
        "dossier": "imprimante_point_de_vente"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/641-plastifieuses"],
        "url": None,
        "page": 0,
        "dossier": "plastifieuse"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/661-compteuse-de-billets"],
        "url": None,
        "page": 0,
        "dossier": "compteuse_de_billet"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/595-montre-femme-tunisie"],
        "url": "https://www.tunisianet.com.tn/595-montre-femme-tunisie?page=",
        "page": 4,
        "dossier": "montre_femme"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/594-montre-homme-tunisie"],
        "url": "https://www.tunisianet.com.tn/594-montre-homme-tunisie?page=",
        "page": 3,
        "dossier": "montre_homme"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/584-fourniture-stylos-feutres-rollers-tunisie"],
        "url": None,
        "page": 0,
        "dossier": "stylos_feutre"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/583-fourniture-stylos-feutres-rollers-tunisie"],
        "url": None,
        "page": 0,
        "dossier": "stylos_feutre_roller"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/478-fourniture-crayons-porte-mines-tunisie"],
        "url": "https://www.tunisianet.com.tn/478-fourniture-crayons-porte-mines-tunisie?page=",
        "page": 3,
        "dossier": "crayon_porte_mine"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/477-fourniture-surligneurs-tunisie"],
        "url": "https://www.tunisianet.com.tn/477-fourniture-surligneurs-tunisie?page=",
        "page": 3,
        "dossier": "surligneur"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/479-fourniture-marqueurs-tunisie"],
        "url": "https://www.tunisianet.com.tn/479-fourniture-marqueurs-tunisie?page=",
        "page": 4,
        "dossier": "marqueur"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/480-fourniture-correction-tunisie"],
        "url": None,
        "page": 0,
        "dossier": "correcteur"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/640-regles"],
        "url": None,
        "page": 0,
        "dossier": "regle"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/653-porte-stylos"],
        "url": None,
        "page": 0,
        "dossier": "porte_stylos"
    },
    {
        "urls": ["https://www.tunisianet.com.tn/655-cachets-tampons"],
        "url": None,
        "page": 0,
        "dossier": "cachet_tampon"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/503-chemises-sous-chemises",
            "https://www.tunisianet.com.tn/505-portes-documents"
        ],
        "url": None,
        "page": 0,
        "dossier": "portes_document"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/449-calculatrice-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/449-calculatrice-tunisie?page=",
        "page": 3,
        "dossier": "calculatrice"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/482-fourniture-decoupe-tunisie"
        ],
        "url": None,
        "page": 0,
        "dossier": "decoupe"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/551-agrafage"
        ],
        "url": "https://www.tunisianet.com.tn/551-agrafage?page=",
        "page": 4,
        "dossier": "agrafeuge"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/625-trombones-pinces"
        ],
        "url": None,
        "page": 0,
        "dossier": "trombone_pince"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/574-tableaux-blancs"
        ],
        "url": None,
        "page": 0,
        "dossier": "tableau_blanc"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/441-switch-routeurs-point-d-acces"
        ],
        "url": "https://www.tunisianet.com.tn/441-switch-routeurs-point-d-acces?page=",
        "page": 5,
        "dossier": "switch_routeurs_point_d_acces"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/442-carte-reseau"
        ],
        "url": None,
        "page": 0,
        "dossier": "carte_reseau"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/443-cle-wifi-bluetooth"
        ],
        "url": None,
        "page": 0,
        "dossier": "cle_wifi_bluetooth"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/673-coffrets-et-armoires-reseau"
        ],
        "url": None,
        "page": 0,
        "dossier": "armoire_reseau"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/674-multiprise"
        ],
        "url": None,
        "page": 0,
        "dossier": "multiprise"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/726-accessoires-reseau"
        ],
        "url": None,
        "page": 0,
        "dossier": "accessoire_reseau"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/350-cables-hdmi"
        ],
        "url": "https://www.tunisianet.com.tn/350-cables-hdmi?page=",
        "page": 3,
        "dossier": "cables_hdmi"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/351-cables-usb"
        ],
        "url": None,
        "page": 0,
        "dossier": "cables_usb"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/352-cables-reseau"
        ],
        "url": "https://www.tunisianet.com.tn/352-cables-reseau?page=",
        "page": 4,
        "dossier": "cable_reseau"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/355-cables-alimentation",
            "https://www.tunisianet.com.tn/354-cables-ecrans-tv-audio-dvd"
        ],
        "url": None,
        "page": 0,
        "dossier": "cable"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/356-adaptateurs-convertisseurs"
        ],
        "url": "https://www.tunisianet.com.tn/356-adaptateurs-convertisseurs?page=",
        "page": 6,
        "dossier": "adaptateur"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/301-pc-portable-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/301-pc-portable-tunisie?page=",
        "page": 28,
        "dossier": "pc_portable"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/681-pc-portable-gamer"
        ],
        "url": "https://www.tunisianet.com.tn/681-pc-portable-gamer?page=",
        "page": 28,
        "dossier": "pc_portable_gamer"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/703-pc-portable-pro"
        ],
        "url": "https://www.tunisianet.com.tn/703-pc-portable-pro?page=",
        "page": 9,
        "dossier": "pc_portable_pro"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/338-casque-ecouteurs"
        ],
        "url": "https://www.tunisianet.com.tn/338-casque-ecouteurs?page=",
        "page": 14,
        "dossier": "casque_ecouteurs"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/331-sacoche-sac-a-dos"
        ],
        "url": "https://www.tunisianet.com.tn/331-sacoche-sac-a-dos?page=",
        "page": 6,
        "dossier": "sacoche_sac_a_dos"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/334-souris-informatique"
        ],
        "url": "https://www.tunisianet.com.tn/334-souris-informatique?page=",
        "page": 12,
        "dossier": "souris"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/704-claviers"
        ],
        "url": "https://www.tunisianet.com.tn/704-claviers?page=",
        "page": 5,
        "dossier": "clavier"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/332-ensemble-clavier-et-souris"
        ],
        "url": "https://www.tunisianet.com.tn/332-ensemble-clavier-et-souris?page=",
        "page": 3,
        "dossier": "clavier_et_souris"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/488-tapis-souris-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/488-tapis-souris-tunisie?page=",
        "page": 3,
        "dossier": "tapis_souris"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/500-refroidisseur"
        ],
        "url": None,
        "page": 0,
        "dossier": "refroidisseur_pc"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/498-hub-usb-lecteur-carte-tunisie"
        ],
        "url": None,
        "page": 0,
        "dossier": "hub_usb_lecteur"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/658-accessoires-ecran"
        ],
        "url": None,
        "page": 0,
        "dossier": "accessoire_ecran"
    },
    
     {
        "urls": [
            "https://www.tunisianet.com.tn/336-webcam"
        ],
        "url": None,
        "page": 0,
        "dossier": "webcam"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/667-ecran-pc-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/667-ecran-pc-tunisie?page=",
        "page": 6,
        "dossier": "ecran_pc"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/373-pc-de-bureau"
        ],
        "url": "https://www.tunisianet.com.tn/373-pc-de-bureau?page=",
        "page": 8,
        "dossier": "pc_de_bureau"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/682-pc-de-bureau-gamer"
        ],
        "url": "https://www.tunisianet.com.tn/682-pc-de-bureau-gamer?page=",
        "page": 8,
        "dossier": "pc_de_bureau_gamer"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/375-serveur-informatique-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/375-serveur-informatique-tunisie?page=",
        "page": 6,
        "dossier": "serveur_informatique"
    },
     {
        "urls": [
            "https://www.tunisianet.com.tn/380-onduleur"
        ],
        "url": "https://www.tunisianet.com.tn/380-onduleur?page=",
        "page": 6,
        "dossier": "onduleur"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/408-disque-dur-interne"
        ],
        "url": None,
        "page": 0,
        "dossier": "disque_dur_interne"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/427-refroidisseur-ventilateur-boitier"
        ],
        "url": "https://www.tunisianet.com.tn/427-refroidisseur-ventilateur-boitier?page=",
        "page": 3,
        "dossier": "refroidisseur_ventilateur_boitier"
    },
          {
        "urls": [
            "https://www.tunisianet.com.tn/421-processeur"
        ],
        "url": None, 
        "page": 0,
        "dossier": "processeur"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/409-barrette-memoire"
        ],
        "url": "https://www.tunisianet.com.tn/409-barrette-memoire?page=", 
        "page": 3,
        "dossier": "barrette_memoire"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/420-carte-mere"
        ],
        "url": None, 
        "page": 0,
        "dossier": "carte_mere"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/410-carte-graphique-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/410-carte-graphique-tunisie?page=", 
        "page": 3,
        "dossier": "carte_graphique"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/412-batterie-pour-pc-portable"
        ],
        "url": None, 
        "page": 0,
        "dossier": "batterie_pour_pc"
    },

# %%
articles = [
    {
        "urls": [
            "https://www.tunisianet.com.tn/411-chargeur-pour-pc-portable"
        ],
        "url": None, 
        "page": 0,
        "dossier": "chargeur_pour_pc"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/423-boite-d-alimentation"
        ],
        "url": "https://www.tunisianet.com.tn/423-boite-d-alimentation?page=", 
        "page": 3,
        "dossier": "boite_alimentation"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/377-telephone-portable-tunisie"
        ],
        "url": None, 
        "page": 0,
        "dossier": "telephone_portable"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/596-smartphone-mobile-4g-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/596-smartphone-mobile-4g-tunisie?page=", 
        "page": 9,
        "dossier": "smartphone_mobile"
    },
     {
        "urls": [
            "https://www.tunisianet.com.tn/515-tablette"
        ],
        "url": None, 
        "page": 0,
        "dossier": "tablette"
    },
     {
        "urls": [
            "https://www.tunisianet.com.tn/728-tablette-graphique"
        ],
        "url": "https://www.tunisianet.com.tn/728-tablette-graphique?page=", 
        "page": 3,
        "dossier": "tablette_graphique"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/516-chargeurs-et-cables-pour-telephones",
            "https://www.tunisianet.com.tn/510-chargeur-et-cable-pour-tablette"
        ],
        "url": "https://www.tunisianet.com.tn/510-chargeur-et-cable-pour-tablette?page=", 
        "page": 5,
        "dossier": "chargeur_et_cable"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/636-power-bank-tunisie"
        ],
        "url": "https://www.tunisianet.com.tn/636-power-bank-tunisie?page=", 
        "page": 3,
        "dossier": "power_bank"
    },
    {
        "urls": [
            "https://www.tunisianet.com.tn/650-smartwatch"
        ],
        "url": "https://www.tunisianet.com.tn/650-smartwatch?page=", 
        "page": 3,
        "dossier": "power_banksmartwatch"
    }
]

# %%
len(articles)
# Out:
# 14

# %%
for article in articles:
    tunisianet_scraping_images(article['urls'], article['url'], article['page'], article['dossier'])
